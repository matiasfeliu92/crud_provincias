# %% [markdown]
# <a href="https://colab.research.google.com/github/matiasfeliu92/crud_provincias/blob/refactor%2Fprov-data/argentine_provinces_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link a regiones argentinas
# https://eviet.cancilleria.gob.ar/es/content/regiones-argentinas-0

# %% [markdown]
# Link a provincias argentinas con sus superficies y poblacion
# https://cdn.educ.ar/dinamico/UnidadHtml__get__c9da45fe-4b48-11e1-82ba-ed15e3c494af/index.html

# %%
import pandas as pd
import psycopg2

# %%
conn = psycopg2.connect("postgresql://matiasmazparrotefeliu:francia1992@postgresql-matiasmazparrotefeliu.alwaysdata.net:5432/matiasmazparrotefeliu_arg_provinces") # USO LA DB DE PRODUCCION PARA CONSULTAR

# %%
df_provinces = pd.read_sql_query("SELECT * FROM \"arg_provinces\" ORDER BY name", conn)
df_provinces
# Out:
# <ipython-input-18-821c53343c71>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_provinces = pd.read_sql_query("SELECT * FROM \"arg_provinces\" ORDER BY name", conn)
#                            name   surface           region  density  \
# 0                  Buenos Aires  307501.0           Pampas    44.96
# 1                     Catamarca  102602.0         Noroeste     3.26
# 2                         Chaco   99633.0          Litoral     9.88
# 3                        Chubut  224686.0        Patagonia     1.84
# 4                       Córdoba  165321.0          Sierras    18.60
# 5                    Corrientes   88199.0          Litoral    10.56
# 6                    Entre Ríos   78781.0          Litoral    14.70
# 7                       Formosa   72066.0          Litoral     6.80
# ...

# %%
df_provinces.describe()
# Out:
#              surface    density    population
# count      23.000000  23.000000  2.300000e+01
# mean   162825.086957  12.411304  1.414427e+06
# std    192377.854632  14.835837  2.616305e+06
# min     22524.000000   0.100000  1.010790e+05
# 25%     83490.000000   3.230000  3.905850e+05
# 50%    102602.000000   6.900000  6.200230e+05
# 75%    160404.500000  13.100000  1.118599e+06
# max    986418.000000  59.400000  1.287720e+07
